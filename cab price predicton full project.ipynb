# %%
import matplotlib.pyplot as plt
import pandas as pd
weather=pd.read_csv('weather.csv')
weather.head()
# Out:
#     temp            location  clouds  pressure    rain  time_stamp  humidity  \
# 0  42.42            Back Bay     1.0   1012.14  0.1228  1545003901      0.77
# 1  42.43         Beacon Hill     1.0   1012.15  0.1846  1545003901      0.76
# 2  42.50   Boston University     1.0   1012.15  0.1089  1545003901      0.76
# 3  42.11              Fenway     1.0   1012.13  0.0969  1545003901      0.77
# 4  43.13  Financial District     1.0   1012.14  0.1786  1545003901      0.75
#
#     wind
# 0  11.25
# 1  11.32
# 2  11.07
# 3  11.09
# 4  11.49

# %%
weather.tail()
# Out:
#        temp                 location  clouds  pressure  rain  time_stamp  \
# 6271  44.72            North Station    0.89   1000.69   NaN  1543819974
# 6272  44.85  Northeastern University    0.88   1000.71   NaN  1543819974
# 6273  44.82            South Station    0.89   1000.70   NaN  1543819974
# 6274  44.78         Theatre District    0.89   1000.70   NaN  1543819974
# 6275  44.69                 West End    0.89   1000.70   NaN  1543819974
#
#       humidity  wind
# 6271      0.96  1.52
# 6272      0.96  1.54
# 6273      0.96  1.54
# 6274      0.96  1.54
# 6275      0.96  1.52

# %%
cabrides=pd.read_csv('cab_rides.csv')
cabrides.head()
# Out:
#    distance cab_type     time_stamp    destination            source  price  \
# 0      0.44     Lyft  1544952607890  North Station  Haymarket Square    5.0
# 1      0.44     Lyft  1543284023677  North Station  Haymarket Square   11.0
# 2      0.44     Lyft  1543366822198  North Station  Haymarket Square    7.0
# 3      0.44     Lyft  1543553582749  North Station  Haymarket Square   26.0
# 4      0.44     Lyft  1543463360223  North Station  Haymarket Square    9.0
#
#    surge_multiplier                                    id    product_id  \
# 0               1.0  424553bb-7174-41ea-aeb4-fe06d4f4b9d7     lyft_line
# 1               1.0  4bd23055-6827-41c6-b23b-3c491f24e74d  lyft_premier
# 2               1.0  981a3613-77af-4620-a42a-0c0866077d1e          lyft
# 3               1.0  c2d88af2-d278-4bfd-a8d0-29ca77cc5512   lyft_luxsuv
# 4               1.0  e0126e1f-8ca9-4f2e-82b3-50505a09db9a     lyft_plus
#
#            name
# 0        Shared
# 1           Lux
# 2          Lyft
# ...

# %%
cabrides.tail()
# Out:
#         distance cab_type     time_stamp destination    source  price  \
# 693066       1.0     Uber  1543708385534   North End  West End   13.0
# 693067       1.0     Uber  1543708385534   North End  West End    9.5
# 693068       1.0     Uber  1543708385534   North End  West End    NaN
# 693069       1.0     Uber  1543708385534   North End  West End   27.0
# 693070       1.0     Uber  1543708385534   North End  West End   10.0
#
#         surge_multiplier                                    id  \
# 693066               1.0  616d3611-1820-450a-9845-a9ff304a4842
# 693067               1.0  633a3fc3-1f86-4b9e-9d48-2b7132112341
# 693068               1.0  64d451d0-639f-47a4-9b7c-6fd92fbd264f
# 693069               1.0  727e5f07-a96b-4ad1-a2c7-9abc3ad55b4e
# 693070               1.0  e7fdc087-fe86-40a5-a3c3-3b2a8badcbda
#
#                                   product_id       name
# 693066  6f72dfc5-27f1-42e8-84db-ccc7a75f6969     UberXL
# ...

# %%
weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6276 entries, 0 to 6275
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   temp        6276 non-null   float64
#  1   location    6276 non-null   object
#  2   clouds      6276 non-null   float64
#  3   pressure    6276 non-null   float64
#  4   rain        894 non-null    float64
#  5   time_stamp  6276 non-null   int64
#  6   humidity    6276 non-null   float64
#  7   wind        6276 non-null   float64
# dtypes: float64(6), int64(1), object(1)
# memory usage: 392.4+ KB

# %%
weather['temp'].unique()
# Out:
# array([42.42, 42.43, 42.5 , ..., 32.76, 35.5 , 39.62])

# %%
plt.figure(figsize=(15,10))
weather['temp'].plot.bar()

# %%
weather['location'].unique()
# Out:
# array(['Back Bay', 'Beacon Hill', 'Boston University', 'Fenway',
#        'Financial District', 'Haymarket Square', 'North End',
#        'North Station', 'Northeastern University', 'South Station',
#        'Theatre District', 'West End'], dtype=object)

# %%
weather['humidity'].unique()
# Out:
# array([0.77, 0.76, 0.75, 0.78, 0.71, 0.72, 0.73, 0.74, 0.9 , 0.91, 0.66,
#        0.67, 0.8 , 0.81, 0.82, 0.86, 0.85, 0.95, 0.89, 0.87, 0.61, 0.6 ,
#        0.69, 0.7 , 0.83, 0.52, 0.53, 0.54, 0.88, 0.92, 0.93, 0.94, 0.55,
#        0.56, 0.58, 0.59, 0.84, 0.79, 0.63, 0.62, 0.65, 0.64, 0.51, 0.57,
#        0.68, 0.46, 0.45, 0.49, 0.48, 0.96, 0.5 , 0.99, 0.98, 0.97, 0.47])

# %%
weather['wind'].unique()
# Out:
# array([11.25, 11.32, 11.07, ..., 17.51, 17.45,  1.53])

# %%
weather['wind'].plot.bar()

# %%
weather.mean()
# Out:
# temp          3.909047e+01
# clouds        6.777772e-01
# pressure      1.008445e+03
# rain          5.765235e-02
# time_stamp    1.543857e+09
# humidity      7.639850e-01
# wind          6.802812e+00
# dtype: float64

# %%
len(weather)
# Out:
# 6276

# %%
weather.describe()
# Out:
#               temp       clouds     pressure        rain    time_stamp  \
# count  6276.000000  6276.000000  6276.000000  894.000000  6.276000e+03
# mean     39.090475     0.677777  1008.445209    0.057652  1.543857e+09
# std       6.022055     0.314284    12.870775    0.100758  6.659340e+05
# min      19.620000     0.000000   988.250000    0.000200  1.543204e+09
# 25%      36.077500     0.440000   997.747500    0.004900  1.543387e+09
# 50%      40.130000     0.780000  1007.660000    0.014850  1.543514e+09
# 75%      42.832500     0.970000  1018.480000    0.060925  1.544691e+09
# max      55.410000     1.000000  1035.120000    0.780700  1.545159e+09
#
#           humidity         wind
# count  6276.000000  6276.000000
# mean      0.763985     6.802812
# std       0.127340     3.633466
# min       0.450000     0.290000
# 25%       0.670000     3.517500
# 50%       0.760000     6.570000
# 75%       0.890000     9.920000
# max       0.990000    18.180000

# %%
weather.shape
# Out:
# (6276, 8)

# %%
weather.isna().sum()
# Out:
# temp             0
# location         0
# clouds           0
# pressure         0
# rain          5382
# time_stamp       0
# humidity         0
# wind             0
# dtype: int64

# %%
weather=weather.dropna(axis=1)

# %%
weather.shape
# Out:
# (6276, 7)

# %%
weather.head()
# Out:
#     temp            location  clouds  pressure  time_stamp  humidity   wind
# 0  42.42            Back Bay     1.0   1012.14  1545003901      0.77  11.25
# 1  42.43         Beacon Hill     1.0   1012.15  1545003901      0.76  11.32
# 2  42.50   Boston University     1.0   1012.15  1545003901      0.76  11.07
# 3  42.11              Fenway     1.0   1012.13  1545003901      0.77  11.09
# 4  43.13  Financial District     1.0   1012.14  1545003901      0.75  11.49

# %%
weather['location'].value_counts()
# Out:
# North Station              523
# South Station              523
# Boston University          523
# Haymarket Square           523
# Fenway                     523
# Back Bay                   523
# Theatre District           523
# North End                  523
# Beacon Hill                523
# Financial District         523
# Northeastern University    523
# West End                   523
# Name: location, dtype: int64

# %%
import seaborn as sns
sns.countplot(weather['location'],label='count')

# %%
sns.pairplot(weather.iloc[:,0:6],hue='location')

# %%
weather.iloc[:,0:6].corr()
# Out:
#                 temp    clouds  pressure  time_stamp  humidity
# temp        1.000000  0.504693 -0.278630   -0.273311  0.387265
# clouds      0.504693  1.000000 -0.079788   -0.097839  0.518758
# pressure   -0.278630 -0.079788  1.000000    0.519631 -0.101814
# time_stamp -0.273311 -0.097839  0.519631    1.000000 -0.288118
# humidity    0.387265  0.518758 -0.101814   -0.288118  1.000000

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,10))
sns.heatmap(weather.iloc[:,0:6].corr(),annot=True,fmt='.0%')

# %%
cabrides.head()
# Out:
#    distance cab_type     time_stamp    destination            source  price  \
# 0      0.44     Lyft  1544952607890  North Station  Haymarket Square    5.0
# 1      0.44     Lyft  1543284023677  North Station  Haymarket Square   11.0
# 2      0.44     Lyft  1543366822198  North Station  Haymarket Square    7.0
# 3      0.44     Lyft  1543553582749  North Station  Haymarket Square   26.0
# 4      0.44     Lyft  1543463360223  North Station  Haymarket Square    9.0
#
#    surge_multiplier                                    id    product_id  \
# 0               1.0  424553bb-7174-41ea-aeb4-fe06d4f4b9d7     lyft_line
# 1               1.0  4bd23055-6827-41c6-b23b-3c491f24e74d  lyft_premier
# 2               1.0  981a3613-77af-4620-a42a-0c0866077d1e          lyft
# 3               1.0  c2d88af2-d278-4bfd-a8d0-29ca77cc5512   lyft_luxsuv
# 4               1.0  e0126e1f-8ca9-4f2e-82b3-50505a09db9a     lyft_plus
#
#            name
# 0        Shared
# 1           Lux
# 2          Lyft
# ...

# %%
cabrides.shape
# Out:
# (693071, 10)

# %%
cabrides.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 693071 entries, 0 to 693070
# Data columns (total 10 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   distance          693071 non-null  float64
#  1   cab_type          693071 non-null  object
#  2   time_stamp        693071 non-null  int64
#  3   destination       693071 non-null  object
#  4   source            693071 non-null  object
#  5   price             637976 non-null  float64
#  6   surge_multiplier  693071 non-null  float64
#  7   id                693071 non-null  object
#  8   product_id        693071 non-null  object
#  9   name              693071 non-null  object
# dtypes: float64(3), int64(1), object(6)
# memory usage: 52.9+ MB

# %%
cabrides.describe()
# Out:
#             distance    time_stamp          price  surge_multiplier
# count  693071.000000  6.930710e+05  637976.000000     693071.000000
# mean        2.189430  1.544046e+12      16.545125          1.013870
# std         1.138937  6.891925e+08       9.324359          0.091641
# min         0.020000  1.543204e+12       2.500000          1.000000
# 25%         1.280000  1.543444e+12       9.000000          1.000000
# 50%         2.160000  1.543737e+12      13.500000          1.000000
# 75%         2.920000  1.544828e+12      22.500000          1.000000
# max         7.860000  1.545161e+12      97.500000          3.000000

# %%
cabrides.isna().sum()
# Out:
# distance                0
# cab_type                0
# time_stamp              0
# destination             0
# source                  0
# price               55095
# surge_multiplier        0
# id                      0
# product_id              0
# name                    0
# dtype: int64

# %%
cabrides['cab_type'].unique()
# Out:
# array(['Lyft', 'Uber'], dtype=object)

# %%
cabrides['name'].unique()
# Out:
# array(['Shared', 'Lux', 'Lyft', 'Lux Black XL', 'Lyft XL', 'Lux Black',
#        'UberXL', 'Black', 'UberX', 'WAV', 'Black SUV', 'UberPool', 'Taxi'],
#       dtype=object)

# %%
cabrides['name'].value_counts()
# Out:
# WAV             55096
# Black SUV       55096
# UberXL          55096
# Black           55095
# Taxi            55095
# UberX           55094
# UberPool        55091
# Lux Black       51235
# Lux             51235
# Lyft            51235
# Lyft XL         51235
# Lux Black XL    51235
# Shared          51233
# Name: name, dtype: int64

# %%
cabrides['product_id'].unique()
# Out:
# array(['lyft_line', 'lyft_premier', 'lyft', 'lyft_luxsuv', 'lyft_plus',
#        'lyft_lux', '6f72dfc5-27f1-42e8-84db-ccc7a75f6969',
#        '6c84fd89-3f11-4782-9b50-97c468b19529',
#        '55c66225-fbe7-4fd5-9072-eab1ece5e23e',
#        '9a0e7b09-b92b-4c41-9779-2ad22b4d779d',
#        '6d318bcc-22a3-4af6-bddd-b409bfce1546',
#        '997acbb5-e102-41e1-b155-9df7de0a73f2',
#        '8cf7e821-f0d3-49c6-8eba-e679c0ebcf6a'], dtype=object)

# %%
cabrides['product_id'].value_counts()
# Out:
# 6d318bcc-22a3-4af6-bddd-b409bfce1546    55096
# 9a0e7b09-b92b-4c41-9779-2ad22b4d779d    55096
# 6f72dfc5-27f1-42e8-84db-ccc7a75f6969    55096
# 6c84fd89-3f11-4782-9b50-97c468b19529    55095
# 8cf7e821-f0d3-49c6-8eba-e679c0ebcf6a    55095
# 55c66225-fbe7-4fd5-9072-eab1ece5e23e    55094
# 997acbb5-e102-41e1-b155-9df7de0a73f2    55091
# lyft_premier                            51235
# lyft_luxsuv                             51235
# lyft_lux                                51235
# lyft_plus                               51235
# lyft                                    51235
# lyft_line                               51233
# Name: product_id, dtype: int64

# %%
cabrides['source'].unique()
# Out:
# array(['Haymarket Square', 'Back Bay', 'North End', 'North Station',
#        'Beacon Hill', 'Boston University', 'Fenway', 'South Station',
#        'Theatre District', 'West End', 'Financial District',
#        'Northeastern University'], dtype=object)

# %%
cabrides['price'].unique()
# Out:
# array([ 5.  , 11.  ,  7.  , 26.  ,  9.  , 16.5 , 10.5 ,  3.  , 27.5 ,
#        13.5 , 12.  , 16.  ,  7.5 ,  5.5 ,   nan,  3.5 ,  8.5 , 15.  ,
#        20.5 , 19.5 , 29.5 ,  9.5 , 22.  , 13.  , 17.  , 10.  , 34.  ,
#        18.5 , 36.  , 22.5 , 32.5 , 25.  , 27.  , 35.  ,  8.  , 23.5 ,
#        14.  , 26.5 , 38.5 , 23.  , 30.5 , 17.5 , 30.  , 36.5 , 12.5 ,
#        33.5 , 21.5 , 38.  , 18.  , 33.  , 32.  ,  6.5 , 11.5 , 31.5 ,
#        28.5 , 24.  , 29.  , 31.  , 42.5 , 41.  , 19.  , 52.5 , 67.5 ,
#        15.5 , 21.  , 45.5 , 28.  , 37.5 , 14.5 , 47.5 ,  4.5 , 40.5 ,
#        55.  , 42.  , 46.5 , 50.5 , 24.5 , 41.5 , 56.  , 25.5 , 39.  ,
#        57.5 , 20.  , 39.5 ,  6.  , 35.5 , 48.5 , 37.  , 45.  , 44.  ,
#        34.5 ,  2.5 , 46.  , 48.  , 47.  , 54.  , 52.  , 62.  , 43.  ,
#        43.5 , 80.  , 65.  , 51.5 , 40.  , 49.5 , 58.  , 75.  , 62.5 ,
#        92.  , 87.  , 64.5 , 87.5 , 73.5 , 44.5 , 80.5 , 89.  , 53.  ,
# ...

# %%
dataset=pd.concat([cabrides,weather],axis=1)

# %%
dataset.head()
# Out:
#    distance cab_type     time_stamp    destination            source  price  \
# 0      0.44     Lyft  1544952607890  North Station  Haymarket Square    5.0
# 1      0.44     Lyft  1543284023677  North Station  Haymarket Square   11.0
# 2      0.44     Lyft  1543366822198  North Station  Haymarket Square    7.0
# 3      0.44     Lyft  1543553582749  North Station  Haymarket Square   26.0
# 4      0.44     Lyft  1543463360223  North Station  Haymarket Square    9.0
#
#    surge_multiplier                                    id    product_id  \
# 0               1.0  424553bb-7174-41ea-aeb4-fe06d4f4b9d7     lyft_line
# 1               1.0  4bd23055-6827-41c6-b23b-3c491f24e74d  lyft_premier
# 2               1.0  981a3613-77af-4620-a42a-0c0866077d1e          lyft
# 3               1.0  c2d88af2-d278-4bfd-a8d0-29ca77cc5512   lyft_luxsuv
# 4               1.0  e0126e1f-8ca9-4f2e-82b3-50505a09db9a     lyft_plus
#
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 693071 entries, 0 to 693070
# Data columns (total 17 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   distance          693071 non-null  float64
#  1   cab_type          693071 non-null  object
#  2   time_stamp        693071 non-null  int64
#  3   destination       693071 non-null  object
#  4   source            693071 non-null  object
#  5   price             637976 non-null  float64
#  6   surge_multiplier  693071 non-null  float64
#  7   id                693071 non-null  object
#  8   product_id        693071 non-null  object
#  9   name              693071 non-null  object
#  10  temp              6276 non-null    float64
#  11  location          6276 non-null    object
#  12  clouds            6276 non-null    float64
#  13  pressure          6276 non-null    float64
#  14  time_stamp        6276 non-null    float64
# ...

# %%
dataset['location'].unique()
# Out:
# array(['Back Bay', 'Beacon Hill', 'Boston University', 'Fenway',
#        'Financial District', 'Haymarket Square', 'North End',
#        'North Station', 'Northeastern University', 'South Station',
#        'Theatre District', 'West End', nan], dtype=object)

# %%
dataset['location'].value_counts()
# Out:
# Back Bay                   523
# South Station              523
# Theatre District           523
# Northeastern University    523
# North End                  523
# Beacon Hill                523
# Boston University          523
# Haymarket Square           523
# North Station              523
# Financial District         523
# Fenway                     523
# West End                   523
# Name: location, dtype: int64

# %%
dataset.describe()
# Out:
#             distance    time_stamp          price  surge_multiplier  \
# count  693071.000000  6.930710e+05  637976.000000     693071.000000
# mean        2.189430  1.544046e+12      16.545125          1.013870
# std         1.138937  6.891925e+08       9.324359          0.091641
# min         0.020000  1.543204e+12       2.500000          1.000000
# 25%         1.280000  1.543444e+12       9.000000          1.000000
# 50%         2.160000  1.543737e+12      13.500000          1.000000
# 75%         2.920000  1.544828e+12      22.500000          1.000000
# max         7.860000  1.545161e+12      97.500000          3.000000
#
#               temp       clouds     pressure    time_stamp     humidity  \
# count  6276.000000  6276.000000  6276.000000  6.276000e+03  6276.000000
# mean     39.090475     0.677777  1008.445209  1.543857e+09     0.763985
# std       6.022055     0.314284    12.870775  6.659340e+05     0.127340
# ...

# %%
dataset1=dataset.drop(['time_stamp','surge_multiplier','id','source'],axis=1)

# %%
dataset1.head()
# Out:
#    distance cab_type    destination  price    product_id          name   temp  \
# 0      0.44     Lyft  North Station    5.0     lyft_line        Shared  42.42
# 1      0.44     Lyft  North Station   11.0  lyft_premier           Lux  42.43
# 2      0.44     Lyft  North Station    7.0          lyft          Lyft  42.50
# 3      0.44     Lyft  North Station   26.0   lyft_luxsuv  Lux Black XL  42.11
# 4      0.44     Lyft  North Station    9.0     lyft_plus       Lyft XL  43.13
#
#              location  clouds  pressure  humidity   wind
# 0            Back Bay     1.0   1012.14      0.77  11.25
# 1         Beacon Hill     1.0   1012.15      0.76  11.32
# 2   Boston University     1.0   1012.15      0.76  11.07
# 3              Fenway     1.0   1012.13      0.77  11.09
# 4  Financial District     1.0   1012.14      0.75  11.49

# %%
dataset1['price'].mean()
# Out:
# 16.545125490614065

# %%
dataset1['price'].std()
# Out:
# 9.324358581419423

# %%
dataset1.describe()
# Out:
#             distance          price         temp       clouds     pressure  \
# count  693071.000000  637976.000000  6276.000000  6276.000000  6276.000000
# mean        2.189430      16.545125    39.090475     0.677777  1008.445209
# std         1.138937       9.324359     6.022055     0.314284    12.870775
# min         0.020000       2.500000    19.620000     0.000000   988.250000
# 25%         1.280000       9.000000    36.077500     0.440000   997.747500
# 50%         2.160000      13.500000    40.130000     0.780000  1007.660000
# 75%         2.920000      22.500000    42.832500     0.970000  1018.480000
# max         7.860000      97.500000    55.410000     1.000000  1035.120000
#
#           humidity         wind
# count  6276.000000  6276.000000
# mean      0.763985     6.802812
# std       0.127340     3.633466
# min       0.450000     0.290000
# 25%       0.670000     3.517500
# 50%       0.760000     6.570000
# 75%       0.890000     9.920000
# ...

# %%
sns.pairplot(dataset1.iloc[:,0:11],hue='location')

# %%
sns.pairplot(dataset1.iloc[:,0:11],hue='destination')

# %%
reviews_filter1=dataset1['price']>26

# %%
filtered_reviews1=dataset1[reviews_filter1]
filtered_reviews1.head()
# Out:
#     distance cab_type              destination  price  \
# 9       1.08     Lyft  Northeastern University   27.5
# 30      2.48     Uber            South Station   27.5
# 37      2.94     Uber                   Fenway   29.5
# 65      1.16     Uber                 West End   27.5
# 80      3.39     Uber            North Station   34.0
#
#                               product_id          name   temp  \
# 9                            lyft_luxsuv  Lux Black XL  43.05
# 30  6d318bcc-22a3-4af6-bddd-b409bfce1546     Black SUV  39.18
# 37  6d318bcc-22a3-4af6-bddd-b409bfce1546     Black SUV  27.27
# 65  6d318bcc-22a3-4af6-bddd-b409bfce1546     Black SUV  45.97
# 80  6d318bcc-22a3-4af6-bddd-b409bfce1546     Black SUV  40.01
#
#             location  clouds  pressure  humidity   wind
# 9      South Station    1.00   1012.12      0.75  11.58
# 30  Haymarket Square    0.83    996.07      0.66  10.73
# 37       Beacon Hill    0.15   1033.40      0.81   2.99
# ...

# %%
reviews_filter2=dataset1['price']>29.5
filtered_reviews2=dataset1[reviews_filter2]
filtered_reviews2.head()
# Out:
#      distance cab_type    destination  price  \
# 80       3.39     Uber  North Station   34.0
# 88       3.39     Uber  North Station   36.0
# 93       2.82     Lyft       West End   32.5
# 101      2.49     Uber       Back Bay   32.5
# 109      3.07     Uber  North Station   35.0
#
#                                product_id          name   temp  \
# 80   6d318bcc-22a3-4af6-bddd-b409bfce1546     Black SUV  40.01
# 88   6d318bcc-22a3-4af6-bddd-b409bfce1546     Black SUV  40.17
# 93                            lyft_luxsuv  Lux Black XL  38.55
# 101  6d318bcc-22a3-4af6-bddd-b409bfce1546     Black SUV  37.94
# 109  6d318bcc-22a3-4af6-bddd-b409bfce1546     Black SUV  36.65
#
#                     location  clouds  pressure  humidity   wind
# 80                  Back Bay    0.95   1000.90      0.81   6.46
# 88   Northeastern University    0.94   1000.91      0.80   6.49
# 93               Beacon Hill    0.75    996.82      0.69  11.05
# ...

# %%
import numpy as np
dataset2=dataset1[['destination','distance','price']]
dataset_df=dataset2.groupby(['destination','distance']).agg(np.max)

# %%
dataset2.head()
# Out:
#      destination  distance  price
# 0  North Station      0.44    5.0
# 1  North Station      0.44   11.0
# 2  North Station      0.44    7.0
# 3  North Station      0.44   26.0
# 4  North Station      0.44    9.0

# %%
dataset_df.head()
# Out:
#                       price
# destination distance
# Back Bay    0.03       27.5
#             0.91       27.0
#             0.97       27.0
#             1.08       23.0
#             1.22       38.0

# %%
len(dataset1['price'].unique())
# Out:
# 148

# %%
count_price=dataset1.groupby('price').count()

# %%
count_price['perc_total']=round(count_price['distance']*100/count_price['distance'].sum(),1)

# %%
count_price
# Out:
#        distance  cab_type  destination  product_id   name  temp  location  \
# price
# 2.5         211       211          211         211    211     1         1
# 3.0        5543      5543         5543        5543   5543    62        62
# 3.5        5063      5063         5063        5063   5063    53        53
# 4.5         419       419          419         419    419     2         2
# 5.0       14084     14084        14084       14084  14084   134       134
# ...         ...       ...          ...         ...    ...   ...       ...
# 87.5          4         4            4           4      4     0         0
# 89.0         11        11           11          11     11     0         0
# 89.5          1         1            1           1      1     0         0
# 92.0          9         9            9           9      9     0         0
# 97.5          1         1            1           1      1     0         0
#
#        clouds  pressure  humidity  wind  perc_total
# price
# ...

# %%
plt.figure(figsize=(20,10))
count_price['perc_total'].plot.bar()

# %%
dataset1.head()
# Out:
#    distance cab_type    destination  price    product_id          name   temp  \
# 0      0.44     Lyft  North Station    5.0     lyft_line        Shared  42.42
# 1      0.44     Lyft  North Station   11.0  lyft_premier           Lux  42.43
# 2      0.44     Lyft  North Station    7.0          lyft          Lyft  42.50
# 3      0.44     Lyft  North Station   26.0   lyft_luxsuv  Lux Black XL  42.11
# 4      0.44     Lyft  North Station    9.0     lyft_plus       Lyft XL  43.13
#
#              location  clouds  pressure  humidity   wind
# 0            Back Bay     1.0   1012.14      0.77  11.25
# 1         Beacon Hill     1.0   1012.15      0.76  11.32
# 2   Boston University     1.0   1012.15      0.76  11.07
# 3              Fenway     1.0   1012.13      0.77  11.09
# 4  Financial District     1.0   1012.14      0.75  11.49

# %%
dataset1.iloc[:,0:11].corr()
# Out:
#           distance     price      temp    clouds  pressure  humidity
# distance  1.000000  0.345061  0.042013  0.054347  0.026539  0.031164
# price     0.345061  1.000000  0.020457  0.030044  0.008173  0.027588
# temp      0.042013  0.020457  1.000000  0.504693 -0.278630  0.387265
# clouds    0.054347  0.030044  0.504693  1.000000 -0.079788  0.518758
# pressure  0.026539  0.008173 -0.278630 -0.079788  1.000000 -0.101814
# humidity  0.031164  0.027588  0.387265  0.518758 -0.101814  1.000000

# %%
plt.figure(figsize=(10,10))
sns.heatmap(dataset.iloc[:,:11].corr(),annot=True,fmt='.0%')

# %%
weather.head()
# Out:
#     temp            location  clouds  pressure  time_stamp  humidity   wind
# 0  42.42            Back Bay     1.0   1012.14  1545003901      0.77  11.25
# 1  42.43         Beacon Hill     1.0   1012.15  1545003901      0.76  11.32
# 2  42.50   Boston University     1.0   1012.15  1545003901      0.76  11.07
# 3  42.11              Fenway     1.0   1012.13  1545003901      0.77  11.09
# 4  43.13  Financial District     1.0   1012.14  1545003901      0.75  11.49

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
lb=LabelEncoder()
weather.iloc[:,1]=lb.fit_transform(weather.iloc[:,1].values)
weather.iloc[:,1]
# Out:
# 0        0
# 1        1
# 2        2
# 3        3
# 4        4
#         ..
# 6271     7
# 6272     8
# 6273     9
# 6274    10
# 6275    11
# Name: location, Length: 6276, dtype: int32

# %%
weather.head()
# Out:
#     temp  location  clouds  pressure  time_stamp  humidity   wind
# 0  42.42         0     1.0   1012.14  1545003901      0.77  11.25
# 1  42.43         1     1.0   1012.15  1545003901      0.76  11.32
# 2  42.50         2     1.0   1012.15  1545003901      0.76  11.07
# 3  42.11         3     1.0   1012.13  1545003901      0.77  11.09
# 4  43.13         4     1.0   1012.14  1545003901      0.75  11.49

# %%
clf=RandomForestClassifier(n_estimators=100,criterion='entropy')
x_train,x_test,y_train,y_test=train_test_split(weather[['temp','clouds','pressure','humidity','wind']],weather[['location']],test_size=0.5,random_state=0)

# %%
clf.fit(x_train,y_train)
# Out:
# C:\Users\souvik\anaconda3\lib\site-packages\ipykernel_launcher.py:1: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   """Entry point for launching an IPython kernel.
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='entropy', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
y_pred=clf.predict(x_test)
print(y_pred)
# Out:
# [ 4  2  7 ...  4 11  1]

# %%
from sklearn import metrics
accuracy=metrics.accuracy_score(y_test,y_pred)
accuracy
# Out:
# 0.082855321861058

# %%
from sklearn.neighbors import KNeighborsClassifier
k_range=range(1,40)
scores={}
score_list=[]
for i in k_range:
    knn=KNeighborsClassifier(n_neighbors=i)
    knn.fit(x_train,y_train)
    y_pred=knn.predict(x_test)
    scores[i]=metrics.accuracy_score(y_test,y_pred)
    score_list.append(metrics.accuracy_score(y_test,y_pred))
scores
# Out:
# C:\Users\souvik\anaconda3\lib\site-packages\ipykernel_launcher.py:7: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   import sys
# C:\Users\souvik\anaconda3\lib\site-packages\ipykernel_launcher.py:7: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   import sys
# C:\Users\souvik\anaconda3\lib\site-packages\ipykernel_launcher.py:7: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   import sys
# C:\Users\souvik\anaconda3\lib\site-packages\ipykernel_launcher.py:7: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   import sys
# ...

# %%
plt.figure(figsize=(20,10))
plt.plot(k_range,score_list)
plt.show()

# %%
scores[i]
# Out:
# 0.0579987253027406
